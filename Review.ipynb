# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\mica lenzo\anaconda3\lib\site-packages (0.0.6)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: kdtree>=0.12 in c:\users\mica lenzo\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# import the citipy module
from citipy import citipy

# %%
# use citipy.nearest_city(lat, lng).city_name to find the nearest city name based on lat and lng coords

# + latitude = north hemisphere / - latitude = southern hemisphere
# + longitude = east of prime meridian / - longitude = west of prime meridian

cityName = citipy.nearest_city(33.748, -84.387).city_name

print(cityName)
# Out:
# atlanta

# %%
# generate a list of lats and lons and then add those to a tuple
# import numpy
import numpy as np

# %%
# set the range of lats and longs for United States
latRange = (24, 50)
lngRange = (-125, -66.9)

# %%
# use np. random.uniform to generate a series of values in a range
lats = np.random.uniform(latRange[0], latRange[1], size=50)
lons = np.random.uniform(lngRange[0], lngRange[1], size=50)

# zip the lists of lats and lons into tuple
latLongs = zip(lats, lons)

# %%
# use nearest_city to identify a city near each set of coordinates
cityNames = []

for coords in latLongs:
    # try to get a city name
    cityName = citipy.nearest_city(coords[0], coords[1]).city_name
   
    # check to see if the city is unique, if so, add to the list
    if cityName not in cityNames:
        cityNames.append(cityName)

for c in cityNames:
    print(c)
# Out:
# cowansville
# port isabel
# abraham's bay
# cadillac
# gillette
# topolobampo
# gering
# morristown
# trail
# truckee
# aberdeen
# upper grand lagoon
# red lion
# benjamin hill
# wilmington
# selma
# central
# spring creek
# rindge
# defiance
# donnacona
# vancleave
# morehead city
# ciudad melchor muzquiz
# waterloo
# floral city
# ellsworth
# kill devil hills
# dalhart
# lampasas
# elko
# yreka
# hamilton
# rosarito
# marathon
# nantucket
# fort drum
# redmond
# lazaro cardenas
# mena
# new ulm
# california
# val-d'or
# whiteville
# cockburn town
# hereford
# la grange
# lewistown
# boiling springs
# teays valley

# %%
import requests
import json
import pandas as pd

# %%
#open weather api key
api_key = "c80ae4b448d2729cfe555b0145c493c2"

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
units = 'imperial'
# build the base query url
queryURL = f"{url}appid={api_key}&units={units}&q="

# %%
city = "Charlotte"
queryURL += city

weather = requests.get(queryURL)

weatherJSON = weather.json() # same as requests.get(queryURL).json()
weatherJSON # ['coord']['lat'] - ['coord']['lon'] - ['main']['temp']
# Out:
# {'coord': {'lon': -80.8431, 'lat': 35.2271},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 57.22,
#   'feels_like': 56.21,
#   'temp_min': 55.02,
#   'temp_max': 59.16,
#   'pressure': 1019,
#   'humidity': 76,
#   'sea_level': 1019,
#   'grnd_level': 993},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 161, 'gust': 10},
#  'clouds': {'all': 0},
#  'dt': 1738632475,
#  'sys': {'type': 2,
#   'id': 2007844,
#   'country': 'US',
#   'sunrise': 1738585252,
#   'sunset': 1738623213},
#  'timezone': -18000,
#  'id': 4460243,
#  'name': 'Charlotte',
#  'cod': 200}

# %%
import time

count = 0

while count < 5:
    time.sleep(1) # pauses the program for 1 sec
    count += 1
    if count == 1:
        print(f"Printed after {count} second")
    else:
        print(f"Printed after {count} seconds")
# Out:
# Printed after 1 second
# Printed after 2 seconds
# Printed after 3 seconds
# Printed after 4 seconds
# Printed after 5 seconds

# %%
# build a dataframe of city names and current temperatures, latitudes, and longitudes
temperatures = []
lats = []
lons = []
cities = []

queryURL = f"{url}appid={api_key}&units={units}&q="

for city in cityNames:
    try:
        time.sleep(1) # pauses the program for 1 sec
        
        # create the new query string
        cityQuery = f"{queryURL}{city}"
        print(cityQuery)
     
        #call to requests and jsonify the response
        response = requests.get(cityQuery).json()
        response

        if response['coord']['lat'] > 50 or response['coord']['lat'] < 24:
            pass
        elif response['coord']['lon'] < -125 or response['coord']['lon'] > -66.9:
            pass
        elif response['sys']['country'] != 'US':
            pass
        else:
            # extract the temperature and add to the temperatures list
            temperatures.append(response['main']['temp'])
      
            # extract the latitude and add to the latitudes list
            lats.append(response['coord']['lat'])
     
            # extract the longitude and add to the logitudes list
            lons.append(response['coord']['lon'])
    
            # extract the city name from Open Weather
            cities.append(response['name'])

    except:
        # just in case the temperature was not reported
        pass

# build the dataframe
cityDataDF = pd.DataFrame(
    {
        "City Name": cities,
        "Fahrenheit Temperature": temperatures,
        "Latitude": lats,
        "Longitude": lons
    }
)

cityDataDF
# Out:
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=cowansville
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=port isabel
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=abraham's bay
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=cadillac
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=gillette
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=topolobampo
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=gering
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=morristown
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=trail
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=truckee
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=aberdeen
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=upper grand lagoon
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=red lion
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=benjamin hill
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=wilmington
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=selma
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=central
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=spring creek
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=rindge
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=defiance
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=donnacona
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=vancleave
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=morehead city
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=ciudad melchor muzquiz
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=waterloo
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=floral city
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=ellsworth
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=kill devil hills
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=dalhart
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=lampasas
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=elko
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=yreka
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=hamilton
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=rosarito
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=marathon
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=nantucket
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=fort drum
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=redmond
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=lazaro cardenas
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=mena
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=new ulm
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=california
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=val-d'or
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=whiteville
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=cockburn town
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=hereford
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=la grange
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=lewistown
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=boiling springs
# https://api.openweathermap.org/data/2.5/weather?appid=c80ae4b448d2729cfe555b0145c493c2&units=imperial&q=teays valley
#              City Name  Fahrenheit Temperature  Latitude  Longitude
# 0          Port Isabel                   71.91   26.0734   -97.2086
# 1             Cadillac                   21.11   44.2519   -85.4012
# 2             Gillette                    0.57   44.2911  -105.5022
# 3               Gering                   15.93   41.8258  -103.6605
# 4           Morristown                   55.36   36.2140   -83.2949
# 5              Truckee                   39.60   39.3280  -120.1833
# 6   Upper Grand Lagoon                   56.59   30.1633   -85.7408
# 7             Red Lion                   39.04   39.9009   -76.6058
# 8           Wilmington                   49.30   34.2257   -77.9447
# 9                Selma                   62.56   36.5708  -119.6121
# 10             Central                   74.80   30.5544   -91.0368
# 11        Spring Creek                   49.71   40.7266  -115.5859
# 12              Rindge                   35.92   42.7512   -72.0098
# 13            Defiance                   39.18   41.3334   -84.4500
# 14           Vancleave                   57.04   30.5405   -88.6875
# 15       Morehead City                   48.06   34.7229   -76.7260
# 16         Floral City                   67.80   28.7500   -82.2968
# 17           Ellsworth                   33.39   44.5434   -68.4195
# 18    Kill Devil Hills                   48.27   36.0307   -75.6760
# 19             Dalhart                   60.82   36.0595  -102.5133
# 20            Lampasas                   68.99   31.2168   -98.2336
# 21                Elko                   51.64   41.0002  -115.5012
# 22               Yreka                   35.78   41.7354  -122.6345
# 23            Hamilton                   61.34   39.1834   -84.5333
# 24            Marathon                   26.13   44.9000   -89.7668
# 25           Nantucket                   39.31   41.2835   -70.0995
# 26           Fort Drum                   32.32   44.0584   -75.7619
# 27             Redmond                   35.33   47.6740  -122.1215
# 28             New Ulm                    9.73   44.3125   -94.4605
# 29          California                   54.68   38.3004   -76.5074
# 30          Whiteville                   55.02   34.3388   -78.7031
# 31           La Grange                   53.35   33.0393   -85.0313
# 32           Lewistown                   35.76   40.5992   -77.5714
# 33     Boiling Springs                   57.63   35.0465   -81.9818
# 34        Teays Valley                   54.32   38.4501   -81.9293

# %%
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1390'>
#   <div id="a5374640-644a-4dcd-b7c1-9fc46b75cad0" data-root-id="p1390" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"12bc88e0-c5d0-4aaf-8a0d-d144f6d51e16":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1390"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1391","attributes":{"plot_id":"p1390","comm_id":"8e56bb124fef485385a03f72a9bdec0e","client_comm_id":"ffc111a883dd452ab0515072c38514f7"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"12bc88e0-c5d0-4aaf-8a0d-d144f6d51e16","roots":{"p1390":"a5374640-644a-4dcd-b7c1-9fc46b75cad0"},"root_ids":["p1390"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
pip install cartopy geoviews pyproj
# Out:
# Requirement already satisfied: cartopy in c:\users\mica lenzo\anaconda3\lib\site-packages (0.24.1)
# Requirement already satisfied: geoviews in c:\users\mica lenzo\anaconda3\lib\site-packages (1.14.0)
# Requirement already satisfied: pyproj in c:\users\mica lenzo\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\mica lenzo\anaconda3\lib\site-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\mica lenzo\anaconda3\lib\site-packages (from cartopy) (3.9.2)
# Requirement already satisfied: shapely>=1.8 in c:\users\mica lenzo\anaconda3\lib\site-packages (from cartopy) (2.0.7)
# Requirement already satisfied: packaging>=21 in c:\users\mica lenzo\anaconda3\lib\site-packages (from cartopy) (24.1)
# Requirement already satisfied: pyshp>=2.3 in c:\users\mica lenzo\anaconda3\lib\site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: bokeh>=3.6.0 in c:\users\mica lenzo\anaconda3\lib\site-packages (from geoviews) (3.6.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\mica lenzo\anaconda3\lib\site-packages (from geoviews) (1.19.1)
# Requirement already satisfied: panel>=1.0.0 in c:\users\mica lenzo\anaconda3\lib\site-packages (from geoviews) (1.5.2)
# Requirement already satisfied: param<3.0,>=1.9.3 in c:\users\mica lenzo\anaconda3\lib\site-packages (from geoviews) (2.1.1)
# Requirement already satisfied: xyzservices in c:\users\mica lenzo\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: certifi in c:\users\mica lenzo\anaconda3\lib\site-packages (from pyproj) (2024.8.30)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\mica lenzo\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\mica lenzo\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\mica lenzo\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\mica lenzo\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\mica lenzo\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\mica lenzo\anaconda3\lib\site-packages (from bokeh>=3.6.0->geoviews) (6.4.1)
# Requirement already satisfied: colorcet in c:\users\mica lenzo\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\mica lenzo\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mica lenzo\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mica lenzo\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mica lenzo\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mica lenzo\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mica lenzo\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: bleach in c:\users\mica lenzo\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\mica lenzo\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: markdown in c:\users\mica lenzo\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\mica lenzo\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\mica lenzo\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\mica lenzo\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\mica lenzo\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\mica lenzo\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mica lenzo\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=3.6.0->geoviews) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mica lenzo\anaconda3\lib\site-packages (from pandas>=1.2->bokeh>=3.6.0->geoviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mica lenzo\anaconda3\lib\site-packages (from pandas>=1.2->bokeh>=3.6.0->geoviews) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mica lenzo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\mica lenzo\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\mica lenzo\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mica lenzo\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mica lenzo\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mica lenzo\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mica lenzo\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.2.3)
# Requirement already satisfied: colorama in c:\users\mica lenzo\anaconda3\lib\site-packages (from tqdm->panel>=1.0.0->geoviews) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
weatherMapPlot = cityDataDF.hvplot.points(
    "Longitude",
    "Latitude",
    geo = True,
    size = "Fahrenheit Temperature",
    scale = 1,
    color = "City Name",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 896,
    frame_height = 504,
    hover_cols = ["City Name", "Fahrenheit Temperature"]
)

weatherMapPlot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (City Name,Fahrenheit Temperature)
